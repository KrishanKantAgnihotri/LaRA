# %%
# !pip install numpy 
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.1 is available.
# You should consider upgrading via the 'C:\Users\krishan.k.agnihotri\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.1 is available.
# You should consider upgrading via the 'C:\Users\krishan.k.agnihotri\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('laptops.csv',encoding='latin-1')
data.head()
# Out:
#    Unnamed: 0 Company      Product   TypeName  Inches  \
# 0           1   Apple  MacBook Pro  Ultrabook    13.3
# 1           2   Apple  Macbook Air  Ultrabook    13.3
# 2           3      HP       250 G6   Notebook    15.6
# 3           4   Apple  MacBook Pro  Ultrabook    15.4
# 4           5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# ...

# %%
data.shape
# Out:
# (1303, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# ...

# %%
data['Ram'] = data['Ram'].str.replace('GB','')

# %%
data['Weight'] = data['Weight'].str.replace('kg','')

# %%
data.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS   1.37      1339.69
# ...

# %%
data['Ram'] = data['Ram'].astype('int32')

# %%
data['Weight']  = data['Weight'].astype('float32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price_euros       1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(8)
# memory usage: 112.1+ KB

# %%
##analyzing data 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(data['Price_euros'])

# %%
data['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = data['Company'],y=data['Price_euros'])

plt.xticks(rotation='vertical')
plt.show()

# %%
data['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = data['TypeName'],y=data['Price_euros'])

plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=data['Inches'],y=data['Price_euros'])
plt.show()

# %%
## analyzing how screen resoulution related to price
data['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
data['IsTouchScreen']=data["ScreenResolution"].apply(lambda x : 1 if 'Touchscreen' in x else 0 )

# %%
data.sample(5)
# Out:
#     Company                                    Product  TypeName  Inches  \
# 394    Dell                              Inspiron 5567  Notebook    15.6
# 75     Asus  FX503VD-E4022T (i7-7700HQ/8GB/1TB/GeForce    Gaming    15.6
# 501      HP      15-BS026nv (i5-7200U/8GB/256GB/Radeon  Notebook    15.6
# 512    Dell                                Vostro 5568  Notebook    15.6
# 87       HP                                     250 G6  Notebook    15.6
#
#       ScreenResolution                          Cpu  Ram     Memory  \
# 394  Full HD 1920x1080   Intel Core i7 7500U 2.7GHz    8  256GB SSD
# 75   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz    8    1TB HDD
# 501           1366x768   Intel Core i5 7200U 2.5GHz    8  256GB SSD
# 512  Full HD 1920x1080   Intel Core i5 7200U 2.5GHz    8    1TB HDD
# 87   Full HD 1920x1080   Intel Core i5 7200U 2.5GHz    8  256GB SSD
#
#                          Gpu       OpSys  Weight  Price_euros  IsTouchScreen
# ...

# %%
data['IsTouchScreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=data['IsTouchScreen'],y=data['Price_euros'])
# Out:
# <AxesSubplot:xlabel='IsTouchScreen', ylabel='Price_euros'>

# %%
data['HasIpsPannel']=data["ScreenResolution"].apply(lambda x : 1 if 'IPS' in x else 0 )
sns.barplot(x=data['HasIpsPannel'],y=data['Price_euros'])
# Out:
# <AxesSubplot:xlabel='HasIpsPannel', ylabel='Price_euros'>

# %%
tmp = data['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
data['X_Res'] = tmp[0]
data['Y_Res'] = tmp[1]
data.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  IsTouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69              0
# ...

# %%
data['X_Res'] = data['X_Res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
data.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  IsTouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69              0
# ...

# %%
data['X_Res'] = data['X_Res'].astype('int')
data['Y_Res'] = data['Y_Res'].astype('int')

# %%
data.corr()['Price_euros']
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price_euros      1.000000
# IsTouchScreen    0.191226
# HasIpsPannel     0.252208
# X_Res            0.556529
# Y_Res            0.552809
# Name: Price_euros, dtype: float64

# %%
data['PPI'] = ((((data['X_Res']**2)+(data['Y_Res']**2))**0.5)/data['Inches']).astype('float')

# %%
data.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  IsTouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69              0
# ...

# %%
data.corr()['Price_euros']
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price_euros      1.000000
# IsTouchScreen    0.191226
# HasIpsPannel     0.252208
# X_Res            0.556529
# Y_Res            0.552809
# PPI              0.473487
# Name: Price_euros, dtype: float64

# %%
data.drop(columns=['ScreenResolution','Inches'],inplace=True)

# %%
data.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_euros  IsTouchScreen  HasIpsPannel  X_Res  Y_Res         PPI
# 0      1339.69              0             1   2560   1600  226.983005
# ...

# %%
data['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
data['CpuName'] = data['Cpu'].apply(lambda x: " ".join(x.split()[0:3]))
data.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_euros  IsTouchScreen  HasIpsPannel  X_Res  Y_Res         PPI  \
# 0      1339.69              0             1   2560   1600  226.983005
# ...

# %%
def fetch_processor(text):
    if text== 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
data['CpuProcessor'] = data['CpuName'].apply(fetch_processor)
data.drop(columns = ['X_Res','Y_Res'],inplace=True)
data.head()
# Out:
#   Company      Product   TypeName                         Cpu  Ram  \
# 0   Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    Price_euros  IsTouchScreen  HasIpsPannel         PPI        CpuName  \
# 0      1339.69              0             1  226.983005  Intel Core i5
# ...

# %%
data['CpuProcessor'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = data['CpuProcessor'],y=data['Price_euros'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
data.drop(columns=['Cpu','CpuName'],inplace=True)
data.head()
# Out:
#   Company      Product   TypeName  Ram               Memory  \
# 0   Apple  MacBook Pro  Ultrabook    8            128GB SSD
# 1   Apple  Macbook Air  Ultrabook    8  128GB Flash Storage
# 2      HP       250 G6   Notebook    8            256GB SSD
# 3   Apple  MacBook Pro  Ultrabook   16            512GB SSD
# 4   Apple  MacBook Pro  Ultrabook    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  IsTouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69              0
# 1        Intel HD Graphics 6000  macOS    1.34       898.94              0
# 2         Intel HD Graphics 620  No OS    1.86       575.00              0
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45              0
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60              0
#
#    HasIpsPannel         PPI   CpuProcessor
# 0             1  226.983005  Intel Core i5
# 1             0  127.677940  Intel Core i5
# ...

# %%
data['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = data['Ram'],y=data['Price_euros'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
data['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
#splitting memory into 4 columns HDD TB SSD HYBRID for better analysis
data['Memory'] = data['Memory'].astype(str).replace('\.0','',regex=True)
data['Memory'] = data['Memory'].str.replace('GB','')
data['Memory'] = data['Memory'].str.replace('TB','000')

# %%
tmp= data["Memory"].str.split("+", n = 1, expand = True)

data["first"]= tmp[0]
data["first"]=data["first"].str.strip()

data["second"]= tmp[1]
data.sample(5)
# Out:
#      Company                                        Product  \
# 1072      HP                                  EliteBook 820
# 868     Acer  TMX349-G2-M-50FS (i5-7200U/8GB/256GB/FHD/W10)
# 1279  Lenovo                             IdeaPad Y700-15ISK
# 697     Asus                                Chromebook Flip
# 293     Dell                                         XPS 15
#
#                 TypeName  Ram            Memory                      Gpu  \
# 1072           Ultrabook    8           256 SSD    Intel HD Graphics 520
# 868             Notebook    8           256 SSD    Intel HD Graphics 620
# 1279            Notebook    8          1000 HDD  Nvidia GeForce GTX 960M
# 697   2 in 1 Convertible    4  64 Flash Storage    Intel HD Graphics 515
# 293             Notebook    8           256 SSD  Nvidia GeForce GTX 1050
#
#            OpSys  Weight  Price_euros  IsTouchScreen  HasIpsPannel  \
# 1072   Windows 7    1.26       1199.0              0             0
# ...

# %%
data["Layer1HDD"] = data["first"].apply(lambda x: 1 if "HDD" in x else 0)
data["Layer1SSD"] = data["first"].apply(lambda x: 1 if "SSD" in x else 0)
data["Layer1Hybrid"] =data["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
data["Layer1Flash_Storage"] = data["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

data['first'] = data['first'].str.replace(r'\D', '',regex=True)

data["second"].fillna("0", inplace = True)

data.head()
# Out:
#   Company      Product   TypeName  Ram             Memory  \
# 0   Apple  MacBook Pro  Ultrabook    8            128 SSD
# 1   Apple  Macbook Air  Ultrabook    8  128 Flash Storage
# 2      HP       250 G6   Notebook    8            256 SSD
# 3   Apple  MacBook Pro  Ultrabook   16            512 SSD
# 4   Apple  MacBook Pro  Ultrabook    8            256 SSD
#
#                             Gpu  OpSys  Weight  Price_euros  IsTouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69              0
# 1        Intel HD Graphics 6000  macOS    1.34       898.94              0
# 2         Intel HD Graphics 620  No OS    1.86       575.00              0
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45              0
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60              0
#
#    HasIpsPannel         PPI   CpuProcessor first second  Layer1HDD  Layer1SSD  \
# 0             1  226.983005  Intel Core i5   128      0          0          1
# ...

# %%
data["Layer2HDD"] = data["second"].apply(lambda x: 1 if "HDD" in x else 0)
data["Layer2SSD"] = data["second"].apply(lambda x: 1 if "SSD" in x else 0)
data["Layer2Hybrid"] = data["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
data["Layer2Flash_Storage"] = data["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
data['second'] = data['second'].str.replace(r'\D', '',regex=True)
data["first"] = data["first"].astype(int)
data["second"] = data["second"].astype(int)

data["HDD"]=(data["first"]*data["Layer1HDD"]+data["second"]*data["Layer2HDD"])
data["SSD"]=(data["first"]*data["Layer1SSD"]+data["second"]*data["Layer2SSD"])
data["Hybrid"]=(data["first"]*data["Layer1Hybrid"]+data["second"]*data["Layer2Hybrid"])
data["Flash_Storage"]=(data["first"]*data["Layer1Flash_Storage"]+data["second"]*data["Layer2Flash_Storage"])

data.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
data.sample(5)
# Out:
#       Company                             Product   TypeName  Ram  \
# 114      Dell                              XPS 13  Ultrabook    8
# 1021  Toshiba                   Portégé Z30-C-16K  Ultrabook    8
# 88       Asus  FX503VM-E4007T (i7-7700HQ/16GB/1TB     Gaming   16
# 487      Dell                              XPS 15   Notebook   16
# 984   Toshiba                     Tecra A40-C-1KF   Notebook    4
#
#                    Memory                      Gpu       OpSys  Weight  \
# 114               256 SSD   Intel UHD Graphics 620  Windows 10    1.21
# 1021              256 SSD    Intel HD Graphics 520  Windows 10    1.20
# 88    128 SSD +  1000 HDD  Nvidia GeForce GTX 1060  Windows 10    2.20
# 487               512 SSD  Nvidia GeForce GTX 1050  Windows 10    2.06
# 984               500 HDD    Intel HD Graphics 520  Windows 10    1.75
#
#       Price_euros  IsTouchScreen  HasIpsPannel         PPI   CpuProcessor  \
# ...

# %%
data.drop(columns=['Memory'],inplace=True)

# %%
data.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros  IsTouchScreen  HasIpsPannel         PPI  \
# 0    1.37      1339.69              0             1  226.983005
# 1    1.34       898.94              0             0  127.677940
# 2    1.86       575.00              0             0  141.211998
# 3    1.83      2537.45              0             1  220.534624
# 4    1.37      1803.60              0             1  226.983005
#
#     CpuProcessor  HDD  SSD  Hybrid  Flash_Storage
# 0  Intel Core i5    0  128       0              0
# ...

# %%
data.corr()['Price_euros']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price_euros      1.000000
# IsTouchScreen    0.191226
# HasIpsPannel     0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price_euros, dtype: float64

# %%
#analyzing remaining columns
data['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
data['GpuName'] = data['Gpu'].apply(lambda x:x.split()[0])
data.head()
# Out:
#   Company      Product   TypeName  Ram                           Gpu  OpSys  \
# 0   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Macbook Air  Ultrabook    8        Intel HD Graphics 6000  macOS
# 2      HP       250 G6   Notebook    8         Intel HD Graphics 620  No OS
# 3   Apple  MacBook Pro  Ultrabook   16            AMD Radeon Pro 455  macOS
# 4   Apple  MacBook Pro  Ultrabook    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros  IsTouchScreen  HasIpsPannel         PPI  \
# 0    1.37      1339.69              0             1  226.983005
# 1    1.34       898.94              0             0  127.677940
# 2    1.86       575.00              0             0  141.211998
# 3    1.83      2537.45              0             1  220.534624
# 4    1.37      1803.60              0             1  226.983005
#
#     CpuProcessor  HDD  SSD  Hybrid  Flash_Storage GpuName
# 0  Intel Core i5    0  128       0              0   Intel
# ...

# %%
data['GpuName'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: GpuName, dtype: int64

# %%
data = data[data['GpuName']!='ARM']

# %%
data['GpuName'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: GpuName, dtype: int64

# %%
sns.barplot(x = data['GpuName'],y=data['Price_euros'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
data.drop(columns = ['Gpu'],inplace=True)
data.head()
# Out:
#   Company      Product   TypeName  Ram  OpSys  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    8  macOS    1.37      1803.60
#
#    IsTouchScreen  HasIpsPannel         PPI   CpuProcessor  HDD  SSD  Hybrid  \
# 0              0             1  226.983005  Intel Core i5    0  128       0
# 1              0             0  127.677940  Intel Core i5    0    0       0
# 2              0             0  141.211998  Intel Core i5    0  256       0
# 3              0             1  220.534624  Intel Core i7    0  512       0
# 4              0             1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage GpuName
# 0              0   Intel
# 1            128   Intel
# 2              0   Intel
# ...

# %%
data['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x = data['OpSys'],y =data['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def filter_os(n):
    if n=='Windows 10' or n=='Windows 7' or n =='Windows 10 S':
        return 'Windows'
    elif n=='macOS'or n=='Mac OS X':
        return 'Mac'
    return 'Others/No OS/Linux'

# %%
data['OS'] = data['OpSys'].apply(filter_os)

# %%
data.head()
# Out:
#   Company      Product   TypeName  Ram  OpSys  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    8  macOS    1.37      1803.60
#
#    IsTouchScreen  HasIpsPannel         PPI   CpuProcessor  HDD  SSD  Hybrid  \
# 0              0             1  226.983005  Intel Core i5    0  128       0
# 1              0             0  127.677940  Intel Core i5    0    0       0
# 2              0             0  141.211998  Intel Core i5    0  256       0
# 3              0             1  220.534624  Intel Core i7    0  512       0
# 4              0             1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage GpuName                  OS
# 0              0   Intel                 Mac
# ...

# %%
data.drop(columns=['OpSys'],inplace=True)

# %%
data.head()
# Out:
#   Company      Product   TypeName  Ram  Weight  Price_euros  IsTouchScreen  \
# 0   Apple  MacBook Pro  Ultrabook    8    1.37      1339.69              0
# 1   Apple  Macbook Air  Ultrabook    8    1.34       898.94              0
# 2      HP       250 G6   Notebook    8    1.86       575.00              0
# 3   Apple  MacBook Pro  Ultrabook   16    1.83      2537.45              0
# 4   Apple  MacBook Pro  Ultrabook    8    1.37      1803.60              0
#
#    HasIpsPannel         PPI   CpuProcessor  HDD  SSD  Hybrid  Flash_Storage  \
# 0             1  226.983005  Intel Core i5    0  128       0              0
# 1             0  127.677940  Intel Core i5    0    0       0            128
# 2             0  141.211998  Intel Core i5    0  256       0              0
# 3             1  220.534624  Intel Core i7    0  512       0              0
# 4             1  226.983005  Intel Core i5    0  256       0              0
#
#   GpuName                  OS
# ...

# %%
sns.barplot(x = data['OS'],y =data['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
##analyzing weight
sns.distplot(data['Weight'])
# Out:
# C:\Users\krishan.k.agnihotri\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=data['Weight'],y=data['Price_euros'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price_euros'>

# %%
data.corr()['Price_euros']['Weight']
# Out:
# 0.20986692455314274

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
### dropping week correlated columns
data.drop(columns=['Flash_Storage','Hybrid','Product'],inplace=True)

# %%
## analysing the price 
sns.distplot(data['Price_euros'])
# Out:
# C:\Users\krishan.k.agnihotri\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price_euros', ylabel='Density'>

# %%
## taking the log as graph was more skewed in raw form 
sns.distplot(np.log(data['Price_euros']))
# Out:
# C:\Users\krishan.k.agnihotri\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price_euros', ylabel='Density'>

# %%
## preparation of input to pass in models
X = data.drop(columns=['Price_euros'])
Y = np.log(data['Price_euros'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  IsTouchScreen  HasIpsPannel  \
# 0      Apple           Ultrabook    8    1.37              0             1
# 1      Apple           Ultrabook    8    1.34              0             0
# 2         HP            Notebook    8    1.86              0             0
# 3      Apple           Ultrabook   16    1.83              0             1
# 4      Apple           Ultrabook    8    1.37              0             1
# ...      ...                 ...  ...     ...            ...           ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80              1             1
# 1299  Lenovo  2 in 1 Convertible   16    1.30              1             1
# 1300  Lenovo            Notebook    2    1.50              0             0
# 1301      HP            Notebook    6    2.19              0             0
# 1302    Asus            Notebook    4    2.20              0             0
#
# ...

# %%
Y
# Out:
# 0       7.200194
# 1       6.801216
# 2       6.354370
# 3       7.838915
# 4       7.497540
#           ...
# 1298    6.458338
# 1299    7.312553
# 1300    5.433722
# 1301    6.638568
# 1302    5.910797
# Name: Price_euros, Length: 1302, dtype: float64

# %%
## Model code starts here

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  IsTouchScreen  HasIpsPannel  \
# 183   Toshiba            Notebook    8    2.00              0             0
# 1141      MSI              Gaming    8    2.40              0             0
# 1049     Asus             Netbook    4    1.20              0             0
# 1020     Dell  2 in 1 Convertible    4    2.08              1             1
# 878      Dell            Notebook    4    2.18              0             0
# ...       ...                 ...  ...     ...            ...           ...
# 466      Acer            Notebook    4    2.20              0             0
# 299      Asus           Ultrabook   16    1.63              0             0
# 493      Acer            Notebook    8    2.20              0             0
# 527    Lenovo            Notebook    8    2.20              0             0
# 1193    Apple           Ultrabook    8    0.92              0             1
#
# ...

# %%
## pipeline for various column using columnTranformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

## importing various algorithms 
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
#LinearRegression

# %%
step1 = ColumnTransformer(transformers= [
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)
print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.8073277448418656
# MAE 0.21017827976428902

# %%
print(np.exp(mean_absolute_error(Y_test,y_pred)),'Euro')
# Out:
# 1.2338980193970568 Euro

# %%
#Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.8127331031311809
# MAE 0.20926802242582976

# %%
#Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.8071853945317102
# MAE 0.21114361613472604

# %%
#KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.803148868705085
# MAE 0.19264883332948846

# %%
#Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.826785361449897
# MAE 0.18889034057409904

# %%
#svm

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.8082689367592829
# MAE 0.20241526848176006

# %%
#random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=25)
    
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.8873814674384475
# MAE 0.15923826883370298

# %%
#ExtraTrees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              bootstrap=True,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.8874920922262539
# MAE 0.15909949757301833

# %%
#adaboost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.7993325732353442
# MAE 0.22419169245986031

# %%
#gradientboost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.8823369393961714
# MAE 0.15986921729848064

# %%
#xgboost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.8872854938915256
# MAE 0.15788485721176918

# %%
#Voting regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,bootstrap=True,max_samples=0.5,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.889167855115607
# MAE 0.16020563205623645

# %%
# from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(Y_test,y_pred))
print('MAE',mean_absolute_error(Y_test,y_pred))
# Out:
# R2 score 0.8822548092325717
# MAE 0.16627249377696537

# %%
###Exporting the Model

# %%
import pickle

pickle.dump(data,open('data.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
data
# Out:
#      Company            TypeName  Ram  Weight  Price_euros  IsTouchScreen  \
# 0      Apple           Ultrabook    8    1.37      1339.69              0
# 1      Apple           Ultrabook    8    1.34       898.94              0
# 2         HP            Notebook    8    1.86       575.00              0
# 3      Apple           Ultrabook   16    1.83      2537.45              0
# 4      Apple           Ultrabook    8    1.37      1803.60              0
# ...      ...                 ...  ...     ...          ...            ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80       638.00              1
# 1299  Lenovo  2 in 1 Convertible   16    1.30      1499.00              1
# 1300  Lenovo            Notebook    2    1.50       229.00              0
# 1301      HP            Notebook    6    2.19       764.00              0
# 1302    Asus            Notebook    4    2.20       369.00              0
#
#       HasIpsPannel         PPI           CpuProcessor   HDD  SSD GpuName  \
# ...

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  IsTouchScreen  HasIpsPannel  \
# 183   Toshiba            Notebook    8    2.00              0             0
# 1141      MSI              Gaming    8    2.40              0             0
# 1049     Asus             Netbook    4    1.20              0             0
# 1020     Dell  2 in 1 Convertible    4    2.08              1             1
# 878      Dell            Notebook    4    2.18              0             0
# ...       ...                 ...  ...     ...            ...           ...
# 466      Acer            Notebook    4    2.20              0             0
# 299      Asus           Ultrabook   16    1.63              0             0
# 493      Acer            Notebook    8    2.20              0             0
# 527    Lenovo            Notebook    8    2.20              0             0
# 1193    Apple           Ultrabook    8    0.92              0             1
#
# ...
